# %% [markdown]
# <a href="https://colab.research.google.com/github/bvishnub/Exploratory-Data-Analysis-on-Play-Store-App-Review/blob/main/EDA_on_Play_Store_App_Review_Vishnu_B.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Project Name**    - Exploratory Data Analysis on Play Store App Review

# %% [markdown]
# ##### **Project Type**    - EDA
# ##### **Contribution**    - Individual

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# **Introduction**
#
# The aim of the project is to analyze the play store app and user review data to come up with actionable insights which can help developers to work on and capture the android market leading to  app making business a success.
#
#
# **Objectives**
#
# - To come up with the actionable insights by deep diving into data and performing analysis.
# - Understanding the app download trends based on Categories , Age groups , Paid or Free, Genres , sizes and all.
# - Understanding  App Ratings and Reviews  pattern and understanding the sentiment of the users for better quality apps development.
# - To find out the appt features and attributes for app development business ensuring positive response and maximum downloads at consumer end leading to high revenue.
#
#
# **Scope**
#
# * **Inclusions**
#
#  * *Rating and Review Analysis* - Analyzing  the mean ratings and reviews of the apps based on downloads and to find out the factors driving positive reviews.
#  - *Sentiment Analyses* - for User review Data , checking polarity and **subjectivity** of apps.
#  - *Merging two Data frames* - to check sentiments for apps category wise and other factors.
#  - *Visualization* - finding out the patterns ,counts , trends via charts to come up with the insights.
#
# * **Exclusions**
#
#  - Analysis is based on provided two data frames only , not including app data from other platforms.
#
#
# **Methodology**
#
# Data analysis approach is as follows :
#
# - **Data Collection** - Data set is provided by the AlmaBetter team. There are two data set Play Store Data and User Review Data.
# - **Data Wrangling** - Handling  missing values , removing duplicates, dealing with outliers.
# - **Exploratory Data Analysis** - Analyzing basic trends , relationship in the data and generating summary statistics and visualizing the same with specific charts plots for better understanding.
#
#
# **Deliverables** :
# * Collab Notebook with the pre-defined Project template format with insights.
#
#
# **Conclusion** :
#
# The project is designed to provide actionable insights into app performance ,user satisfaction and market trends  which will be helpful for developers to consider while developing app to ensure positive response from the consumer.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# https://github.com/bvishnub/Exploratory-Data-Analysis-on-Play-Store-App-Review

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# To determine the essential factors driving app development and success, helping developers refine their strategies and excel in the Android market.

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
# To extract actionable insights on app performance, user satisfaction, and market trends, empowering developers to craft high-impact apps that dominate the Android market, resulting in significant profit and revenue growth for the organization.

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 20 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns


from google.colab import drive
drive.mount('/content/drive')

#changing current directory for project directory
os.chdir("/content/drive/MyDrive/AlmaBetter/Project-Module-2")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
os.getcwd()
# !ls
# Out:
# 'EDA on Play Store App Review Vishnu B.ipynb'  'Play Store Data.csv'  'User Reviews.csv'

# %% [markdown]
# ### Dataset Loading

# %%
# Load Dataset
#loading Play store data set
df_playstore=pd.read_csv("Play Store Data.csv")

#loading user review data set
df_user_reveiw=pd.read_csv("User Reviews.csv")

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look
df_playstore.head(5)
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %%
df_playstore.tail(5)
# Out:
#                                                  App             Category  \
# 10836                               Sya9a Maroc - FR               FAMILY
# 10837               Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                         Parkinson Exercices FR              MEDICAL
# 10839                  The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840  iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
#        Rating Reviews                Size     Installs  Type Price  \
# 10836     4.5      38                 53M       5,000+  Free     0
# 10837     5.0       4                3.6M         100+  Free     0
# 10838     NaN       3                9.5M       1,000+  Free     0
# 10839     4.5     114  Varies with device       1,000+  Free     0
# 10840     4.5  398307                 19M  10,000,000+  Free     0
#
#       Content Rating             Genres      Last Updated         Current Ver  \
# ...

# %%
df_user_reveiw.head(5)
# Out:
#                      App                                  Translated_Review  \
# 0  10 Best Foods for You  I like eat delicious food. That's I'm cooking ...
# 1  10 Best Foods for You    This help eating healthy exercise regular basis
# 2  10 Best Foods for You                                                NaN
# 3  10 Best Foods for You         Works great especially going grocery store
# 4  10 Best Foods for You                                       Best idea us
#
#   Sentiment  Sentiment_Polarity  Sentiment_Subjectivity
# 0  Positive                1.00                0.533333
# 1  Positive                0.25                0.288462
# 2       NaN                 NaN                     NaN
# 3  Positive                0.40                0.875000
# 4  Positive                1.00                0.300000

# %%
df_user_reveiw.tail(5)
# Out:
#                                App Translated_Review Sentiment  \
# 64290  Houzz Interior Design Ideas               NaN       NaN
# 64291  Houzz Interior Design Ideas               NaN       NaN
# 64292  Houzz Interior Design Ideas               NaN       NaN
# 64293  Houzz Interior Design Ideas               NaN       NaN
# 64294  Houzz Interior Design Ideas               NaN       NaN
#
#        Sentiment_Polarity  Sentiment_Subjectivity
# 64290                 NaN                     NaN
# 64291                 NaN                     NaN
# 64292                 NaN                     NaN
# 64293                 NaN                     NaN
# 64294                 NaN                     NaN

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
print(f"Playstore data shape{df_playstore.shape}")
print(f"User Review data shape{df_user_reveiw.shape}")
# Out:
# Playstore data shape(10841, 13)
# User Review data shape(64295, 5)

# %% [markdown]
# ### Dataset Information - Playstore Data

# %%
# Dataset Info
df_playstore.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  object
#  4   Size            10841 non-null  object
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(1), object(12)
# memory usage: 1.1+ MB

# %%
df_playstore.describe(include="all")
# Out:
#            App Category       Rating Reviews                Size    Installs  \
# count    10841    10841  9367.000000   10841               10841       10841
# unique    9660       34          NaN    6002                 462          22
# top     ROBLOX   FAMILY          NaN       0  Varies with device  1,000,000+
# freq         9     1972          NaN     596                1695        1579
# mean       NaN      NaN     4.193338     NaN                 NaN         NaN
# std        NaN      NaN     0.537431     NaN                 NaN         NaN
# min        NaN      NaN     1.000000     NaN                 NaN         NaN
# 25%        NaN      NaN     4.000000     NaN                 NaN         NaN
# 50%        NaN      NaN     4.300000     NaN                 NaN         NaN
# 75%        NaN      NaN     4.500000     NaN                 NaN         NaN
# max        NaN      NaN    19.000000     NaN                 NaN         NaN
#
# ...

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count
#considering App name as unique , checking if any duplicate exist
print(f" \t\t\t\t\t\t\tDuplicate Apps : {df_playstore.App.duplicated().sum()} ")

#And 1181 - duplicate  app names

print(df_playstore["App"].value_counts())
print("*"*100)


#we can observe , there are 483 dublicate rows as well
print(f" \t\t\t\t\t\t\tDuplicate rows : {df_playstore.duplicated().sum()}")
df_playstore.loc[df_playstore.duplicated()].head(5)
# Out:
#  							Duplicate Apps : 1181
# App
# ROBLOX                                                9
# CBS Sports App - Scores, News, Stats & Watch Live     8
# ESPN                                                  7
# Duolingo: Learn Languages Free                        7
# Candy Crush Saga                                      7
#                                                      ..
# Meet U - Get Friends for Snapchat, Kik & Instagram    1
# U-Report                                              1
# U of I Community Credit Union                         1
# Waiting For U Launcher Theme                          1
# iHoroscope - 2018 Daily Horoscope & Astrology         1
# Name: count, Length: 9660, dtype: int64
# ****************************************************************************************************
#  							Duplicate rows : 483
#                               App  Category  Rating Reviews  \
# 229  Quick PDF Scanner + OCR FREE  BUSINESS     4.2   80805
# ...

# %%
#Removing duplicates rows
df_playstore.drop_duplicates(inplace=True)
df_playstore.drop_duplicates(subset="App",inplace=True)
print(f"{df_playstore.shape} are the new number of rows and colums after removing duplicate Apps and Rows" )
# Out:
# (9660, 13) are the new number of rows and colums after removing duplicate Apps and Rows

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
print("\t\t\t\tNull_Value")
print(df_playstore.isna().sum())
print("*"*100)
print("\t\t\t\tNull_Value %")

#finding the % of null values using for loop
for i in df_playstore.columns:
  print(f"{i} - {round((df_playstore[i].isna().sum()/len(df_playstore[i]))*100,2)}%")
# Out:
# 				Null_Value
# App                  0
# Category             0
# Rating            1463
# Reviews              0
# Size                 0
# Installs             0
# Type                 1
# Price                0
# Content Rating       1
# Genres               0
# Last Updated         0
# Current Ver          8
# Android Ver          3
# dtype: int64
# ****************************************************************************************************
# 				Null_Value %
# App - 0.0%
# Category - 0.0%
# Rating - 15.14%
# Reviews - 0.0%
# Size - 0.0%
# Installs - 0.0%
# Type - 0.01%
# Price - 0.0%
# Content Rating - 0.01%
# Genres - 0.0%
# Last Updated - 0.0%
# Current Ver - 0.08%
# Android Ver - 0.03%

# %%
# Visualizing the missing values
sns.heatmap(df_playstore.isna(),cbar=False)
#since majority of columns are object data type , we can only see null values of rating , in above cell we can check android ver and current vers content rating ,type also have null values present
# Out:
# <Axes: >

# %% [markdown]
# ### Dataset Information - User Review Data

# %%
# Dataset Info
df_user_reveiw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64295 entries, 0 to 64294
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   App                     64295 non-null  object
#  1   Translated_Review       37427 non-null  object
#  2   Sentiment               37432 non-null  object
#  3   Sentiment_Polarity      37432 non-null  float64
#  4   Sentiment_Subjectivity  37432 non-null  float64
# dtypes: float64(2), object(3)
# memory usage: 2.5+ MB

# %%
df_user_reveiw.describe()
# Out:
#        Sentiment_Polarity  Sentiment_Subjectivity
# count        37432.000000            37432.000000
# mean             0.182146                0.492704
# std              0.351301                0.259949
# min             -1.000000                0.000000
# 25%              0.000000                0.357143
# 50%              0.150000                0.514286
# 75%              0.400000                0.650000
# max              1.000000                1.000000

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count


print(f"duplicate rows count is {df_user_reveiw.duplicated().sum()}")
print(f"duplicate rows {df_user_reveiw.duplicated().sum()/len(df_user_reveiw)*100} %")
# Out:
# duplicate rows count is 33616
# duplicate rows 52.284003421727974 %

# %%
#removing duplicates rows and checking null values again
df_user_reveiw.drop_duplicates(inplace=True)
print(f"duplicate rows count is {df_user_reveiw.duplicated().sum()}")
print(f"duplicate rows {df_user_reveiw.duplicated().sum()/len(df_user_reveiw)*100} %")
print(f"New shape of the data frame is {df_user_reveiw.shape}")
# Out:
# duplicate rows count is 0
# duplicate rows 0.0 %
# New shape of the data frame is (30679, 5)

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
print("\t\t\t\tNull_Value")
print(df_user_reveiw.isna().sum())
print("*"*100)
print("\t\t\t\tNull_Value %")

#finding the % of null values using for loop
for i in df_user_reveiw.columns:
  print(f"{i} - {round((df_user_reveiw[i].isna().sum()/len(df_user_reveiw[i]))*100,2)}%")
# Out:
# 				Null_Value
# App                         0
# Translated_Review         987
# Sentiment                 982
# Sentiment_Polarity        982
# Sentiment_Subjectivity    982
# dtype: int64
# ****************************************************************************************************
# 				Null_Value %
# App - 0.0%
# Translated_Review - 3.22%
# Sentiment - 3.2%
# Sentiment_Polarity - 3.2%
# Sentiment_Subjectivity - 3.2%

# %%
# Visualizing the missing values
sns.heatmap(df_user_reveiw.isna(),cbar=False)
# Out:
# <Axes: >

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# **There are two data sets given**
# * **Playstore Data**-having the google play store application details including ratings ,reviews ,size of the app, installs,android version and many more.
#   * Shape of the data is 10841 rows and 13 columns with duplicate values and null values are present in Rating ,Type, content Rating , Currnet version and Android version.
#   * After removing duplicates rows new shape of the data frame is 9660 rows and 13 columns
#   * 15% null values are present in the data which needs to be imputed.
#
# * **User Review Data**- having details of App with overall sentiment of the consumer -Translated Review,Sentiment, Sentiment Polarity,Sentiment Subjectivity are given.
#   * Shape of data is 64295 rows 5 and columns with duplicates and around 3.22% null values are present in Translated Review,Sentiment, Sentiment Polarity,Sentiment Subjectivity columns which needs to handled.
#   * After removing duplicates rows new shape of the data frame is 30679 rows and 5 columns.

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
print(f"\t\t\t\tPlaystore Columns")
print(df_playstore.columns)
print(f"\t\t\t\tUser Review Columns")
print(df_user_reveiw.columns)
# Out:
# 				Playstore Columns
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='object')
# 				User Review Columns
# Index(['App', 'Translated_Review', 'Sentiment', 'Sentiment_Polarity',
#        'Sentiment_Subjectivity'],
#       dtype='object')

# %%
# Dataset Describe - Play store Data Set
df_playstore.describe(include="all")
# Out:
#                                                    App Category       Rating  \
# count                                             9660     9660  8197.000000
# unique                                            9660       34          NaN
# top     Photo Editor & Candy Camera & Grid & ScrapBook   FAMILY          NaN
# freq                                                 1     1832          NaN
# mean                                               NaN      NaN     4.175052
# std                                                NaN      NaN     0.561026
# min                                                NaN      NaN     1.000000
# 25%                                                NaN      NaN     4.000000
# 50%                                                NaN      NaN     4.300000
# 75%                                                NaN      NaN     4.500000
# max                                                NaN      NaN    19.000000
#
# ...

# %%
#finding out which columns can be converted to numeric

#creating empty list to append data to convert to DataFrame later on
Categories =[]
Unique_Value_Count=[]
Percentage_Unique_Value=[]


#using for loop to iterat through each columns and finding out unique values and % + appending to list
for i in df_playstore.columns:
  Categories.append(i)
  Unique_Value_Count.append(len(df_playstore[i].unique()))
  Percentage_Unique_Value.append(round((df_playstore[i].nunique()/len(df_playstore[i]))*100,2))

#creating Data frame to check
variable_checks=pd.DataFrame({"Coulumns" : Categories,"Unique_Value_Count" : Unique_Value_Count,"%_Unique_Value": Percentage_Unique_Value })
variable_checks
# Out:
#           Coulumns  Unique_Value_Count  %_Unique_Value
# 0              App                9660          100.00
# 1         Category                  34            0.35
# 2           Rating                  41            0.41
# 3          Reviews                5331           55.19
# 4             Size                 462            4.78
# 5         Installs                  22            0.23
# 6             Type                   4            0.03
# 7            Price                  93            0.96
# 8   Content Rating                   7            0.06
# 9           Genres                 119            1.23
# 10    Last Updated                1378           14.27
# 11     Current Ver                2819           29.17
# 12     Android Ver                  34            0.34

# %% [markdown]
# ### Variables Description

# %% [markdown]
# **Play Store App**
#
# * **App** - Name of the application (unique)
# * **Category**- App category and categorical in nature
# ***Rating** - Average rating of the app
# ***Reviews** - Count of reveiws for the app and categorical in nature and 55% unique value, needs to be converted to numerical.
# ***Size**- stands for size of the application in MB and KB , need to be converted to numerical.
# ***Installs**- total number of downloads of respective app,need to converted to numerical.
# ***Type**- Free or Paid distinguish among app.
# ***Price** - Instalation charges,needs to be converted to numerical.
# ***Content** - which age group can download the app - categorical in nature
# ***Genre** - Genre of the app.
# ***Last Updated** - Date when app was last updated needs to converted to datetime.
# ***Current Ver**- current version of the app
# ***Android Ver** - Android version required to download the app.
#
# **User Review Dataset**
# * **App**-Name of the application
#
# * **Translated_Review** - Transalation of the review given by customer about the application
# * **Sentiment** - Sentiment of the consumer +ve , -ve or neutral.
# * **Sentiment_Polarity** -Polarity of the review and range is [-1,1]
# * **Sentiment_Subjectivity**- Range is [0,1].Helps in understanding whether the feedback is based on personal preferences or factual issues.

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.
#Playstore Columns
print("\t\t\t\t\tUnique_values_in_each_columns")
print("\t\t\t\t******************************************")
print("\n")
for i in df_playstore.columns:
  print(f"{i}:- {df_playstore[i].unique()}")
  print("\n")
  print("*"*100)
# Out:
# 					Unique_values_in_each_columns
# 				******************************************
#
#
# App:- ['Photo Editor & Candy Camera & Grid & ScrapBook' 'Coloring book moana'
#  'U Launcher Lite – FREE Live Cool Themes, Hide Apps' ...
#  'Parkinson Exercices FR' 'The SCP Foundation DB fr nn5n'
#  'iHoroscope - 2018 Daily Horoscope & Astrology']
#
#
# ****************************************************************************************************
# Category:- ['ART_AND_DESIGN' 'AUTO_AND_VEHICLES' 'BEAUTY' 'BOOKS_AND_REFERENCE'
#  'BUSINESS' 'COMICS' 'COMMUNICATION' 'DATING' 'EDUCATION' 'ENTERTAINMENT'
#  'EVENTS' 'FINANCE' 'FOOD_AND_DRINK' 'HEALTH_AND_FITNESS' 'HOUSE_AND_HOME'
#  'LIBRARIES_AND_DEMO' 'LIFESTYLE' 'GAME' 'FAMILY' 'MEDICAL' 'SOCIAL'
#  'SHOPPING' 'PHOTOGRAPHY' 'SPORTS' 'TRAVEL_AND_LOCAL' 'TOOLS'
#  'PERSONALIZATION' 'PRODUCTIVITY' 'PARENTING' 'WEATHER' 'VIDEO_PLAYERS'
#  'NEWS_AND_MAGAZINES' 'MAPS_AND_NAVIGATION' '1.9']
#
#
# ...

# %%
# checking unique values in each columns for better understanding
#User Review columns
print("\t\t\t\t\tUnique_values_in_each_columns")
print("\t\t\t\t******************************************")
print("\n")
for i in df_user_reveiw.columns:
  print(f"{i}:- {df_user_reveiw[i].unique()}")
  print("\n")
  print("*"*100)
# Out:
# 					Unique_values_in_each_columns
# 				******************************************
#
#
# App:- ['10 Best Foods for You' '104 找工作 - 找工作 找打工 找兼職 履歷健檢 履歷診療室' '11st' ...
#  'Hotwire Hotel & Car Rental App' 'Housing-Real Estate & Property'
#  'Houzz Interior Design Ideas']
#
#
# ****************************************************************************************************
# Translated_Review:- ['I like eat delicious food. That\'s I\'m cooking food myself, case "10 Best Foods" helps lot, also "Best Before (Shelf Life)"'
#  'This help eating healthy exercise regular basis' nan ...
#  'Dumb app, I wanted post property rent give option. Website work. Waste time space phone.'
#  'I property business got link SMS happy performance still guys need raise bar guys Cheers'
#  'Useless app, I searched flats kondapur, Hyderabad . None number reachable I know flats unavailable would keep posts active']
#
#
# ...

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %% [markdown]
# ### Data Wrangling on Playstore Dataframe

# %%
# Write your code to make your dataset analysis ready.

#checking outliers in Ratings columns before considering mean or median value to impute against null values

print(df_playstore["Rating"].describe())

sns.boxplot(x=df_playstore["Rating"])
# Out:
# count    8197.000000
# mean        4.175052
# std         0.561026
# min         1.000000
# 25%         4.000000
# 50%         4.300000
# 75%         4.500000
# max        19.000000
# Name: Rating, dtype: float64
# <Axes: xlabel='Rating'>

# %%
 #we can observe in the above plot that there is a single data which is more than 5 rating ideally it should be 5 or below 5 because rating should 1-5 as per data
df_playstore.drop(df_playstore.loc[df_playstore["Rating"]>5].index,inplace=True) #removing the outlier

#we can observe outliers are present , so we can continue to fill null values with the median

# %%
#filling the Null values with median of the column
df_playstore["Rating"].fillna(df_playstore["Rating"].median(),inplace=True)

#checking if null value removed or not
print(df_playstore["Rating"].isnull().sum())

#checking shape of the data frame now
print(f"{df_playstore.shape}-shape")
# Out:
# 0
# (9659, 13)-shape

# %%
#droping remaining rows ("Type","Content Rating",'Current Ver',"Android Ver") containing null values as null values were very less ieven less than 0.5%

df_playstore.dropna(subset=["Type","Content Rating",'Current Ver',"Android Ver"],axis=0,inplace=True)

#checking if null values still exists or not
print(df_playstore.isnull().sum())
# Out:
# App               0
# Category          0
# Rating            0
# Reviews           0
# Size              0
# Installs          0
# Type              0
# Price             0
# Content Rating    0
# Genres            0
# Last Updated      0
# Current Ver       0
# Android Ver       0
# dtype: int64

# %%
#converting datatype of Reviews to integer type and Last Update to date time for futher analysis

df_playstore["Reviews"]=df_playstore["Reviews"].astype("int")
df_playstore["Last Updated"]=pd.to_datetime(df_playstore["Last Updated"])

# %%
#Function to remove m and k from size columns + converting KB to MB

def check(n):
  #if condition checking for m in string and removing same and returning
    if n[-1] not in "Kk":
      string=""
      #for loop used to run through string and check presence of m in element
      for i in n:
        if i not in "mM":
          string+=i
      #returning string after removing m from complete string
      return string
    #eslse condition checking for k and converting to MB and returnig
    else:
      string=""
      #for loop used to run through string and check presence of k in element
      for i in n:
        if i not in "kK":
          string+=i
      string=round(float(string)/1024,1)
      #after conversion to MB retruning string only
      return str(string)



#using apply method with lambda and fucntion to remove m and k elements from all the elements in the column
df_playstore["Size"]=df_playstore.apply(lambda x : check(x["Size"]),axis=1)

#checking the unique value now and we can observe size 'Varies with device' present in columns which needs to be considered before converting size column to numerical
df_playstore["Size"].unique()
# Out:
# array(['19', '14', '8.7', '25', '2.8', '5.6', '29', '33', '3.1', '28',
#        '12', '20', '21', '37', '5.5', '17', '39', '31', '4.2', '7.0',
#        '23', '6.0', '6.1', '4.6', '9.2', '5.2', '11', '24',
#        'Varies with device', '9.4', '15', '10', '1.2', '26', '8.0', '7.9',
#        '56', '57', '35', '54', '0.2', '3.6', '5.7', '8.6', '2.4', '27',
#        '2.7', '2.5', '16', '3.4', '8.9', '3.9', '2.9', '38', '32', '5.4',
#        '18', '1.1', '2.2', '4.5', '9.8', '52', '9.0', '6.7', '30', '2.6',
#        '7.1', '3.7', '22', '7.4', '6.4', '3.2', '8.2', '9.9', '4.9',
#        '9.5', '5.0', '5.9', '13', '73', '6.8', '3.5', '4.0', '2.3', '7.2',
#        '2.1', '42', '7.3', '9.1', '55', '0.0', '6.5', '1.5', '7.5', '51',
#        '41', '48', '8.5', '46', '8.3', '4.3', '4.7', '3.3', '40', '7.8',
#        '8.8', '6.6', '5.1', '61', '66', '0.1', '8.4', '44', '0.7', '1.6',
#        '6.2', '53', '1.4', '3.0', '5.8', '3.8', '9.6', '45', '63', '49',
# ...

# %%
#replacing all varies with device records to null values
df_playstore["Size"].replace("Varies with device",np.nan,inplace=True)

#converting the entire size column to numerical after replacing with null values
df_playstore["Size"]=df_playstore["Size"].astype("float")

#checking null values in size columns and it's count and percentage to proceed with correct action

# %%
size_null=df_playstore["Size"].isnull().sum()
size_null_percentage= round(df_playstore["Size"].isnull().sum()/len(df_playstore["Size"]) *100,2)

print(f"Total Null values in size columns is {size_null}  and {size_null_percentage} % ")

#we cannot drope around 14.74% null values , need to impute
# Out:
# Total Null values in size columns is 1226  and 12.71 %

# %%
#checking outliers in Size columns before considering mean or median value to impute against null values

print(df_playstore["Size"].describe())

sns.boxplot(x=df_playstore["Size"])

#we can observe outliers are present , so we can continue to fill null values with the median
# Out:
# count    8422.000000
# mean       20.413524
# std        21.833516
# min         0.000000
# 25%         4.600000
# 50%        12.000000
# 75%        28.000000
# max       100.000000
# Name: Size, dtype: float64
# <Axes: xlabel='Size'>

# %%
#filling null values with median of size columns
df_playstore["Size"].replace(np.nan,df_playstore["Size"].median(),inplace=True)

#checking if null values still exists or not
print(df_playstore["Size"].isnull().sum())
# Out:
# 0

# %%
#fucntion to remove "+" and "," from the elements of installs and converting to integers
def remove(element):
  string=""
  for i in element:
    if i not in "+,":
      string+=i
  return int(string)

#using apply method to with remove fucntion and co
df_playstore["Installs"]=df_playstore["Installs"].apply(remove)

# %%
#fucntion to remove "$"from price column  and converting to float
def remove_dollar(element):
  string=""
  for i in element:
    if i not in "$":
      string+=i
  return float(string)
''
  #using apply method to with remove fucntion and co
df_playstore["Price"]=df_playstore["Price"].apply(remove_dollar)

# %% [markdown]
# ### Data Wrangling on User Review Data Frame

# %%
df_user_reveiw.head(1)
# Out:
#                      App                                  Translated_Review  \
# 0  10 Best Foods for You  I like eat delicious food. That's I'm cooking ...
#
#   Sentiment  Sentiment_Polarity  Sentiment_Subjectivity
# 0  Positive                 1.0                0.533333

# %%
#checking shape of the data frame
print(f"shape of dataframe is {df_user_reveiw.shape}")
print("\n")

#check data info and null values
print("\t\t\t\t Info About Data ")
print(df_user_reveiw.info())

# Missing Values/Null Values Count
print("\t\t\t\tNull_Value_count")
print(df_user_reveiw.isna().sum())
print("*"*100)
print("\t\t\t\tNull_Value %")

#finding the % of null values using for loop
for i in df_user_reveiw.columns:
  print(f"{i} - {round((df_user_reveiw[i].isna().sum()/len(df_user_reveiw[i]))*100,2)}%")
# Out:
# shape of dataframe is (30679, 5)
#
#
# 				 Info About Data
# <class 'pandas.core.frame.DataFrame'>
# Index: 30679 entries, 0 to 64236
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   App                     30679 non-null  object
#  1   Translated_Review       29692 non-null  object
#  2   Sentiment               29697 non-null  object
#  3   Sentiment_Polarity      29697 non-null  float64
#  4   Sentiment_Subjectivity  29697 non-null  float64
# dtypes: float64(2), object(3)
# memory usage: 1.4+ MB
# None
# 				Null_Value_count
# App                         0
# Translated_Review         987
# Sentiment                 982
# Sentiment_Polarity        982
# Sentiment_Subjectivity    982
# dtype: int64
# ****************************************************************************************************
# 				Null_Value %
# App - 0.0%
# Translated_Review - 3.22%
# Sentiment - 3.2%
# ...

# %%
#checking null values
df_user_reveiw.loc[df_user_reveiw["Sentiment"].isna() & df_user_reveiw["Sentiment_Polarity"].isna()& df_user_reveiw["Sentiment_Subjectivity"].isna()]
# Out:
#                                                     App Translated_Review  \
# 2                                 10 Best Foods for You               NaN
# 362                     1LINE – One Line with One Touch               NaN
# 405    2018Emoji Keyboard 😂 Emoticons Lite -sticker&gif               NaN
# 539                 2Date Dating App, Love and matching               NaN
# 628                                           2RedBeans               NaN
# ...                                                 ...               ...
# 64082    Hotspot Shield Free VPN Proxy & Wi-Fi Security               NaN
# 64119                                           Hotstar               NaN
# 64156                    Hotwire Hotel & Car Rental App               NaN
# 64202                    Housing-Real Estate & Property               NaN
# 64236                       Houzz Interior Design Ideas               NaN
#
#       Sentiment  Sentiment_Polarity  Sentiment_Subjectivity
# ...

# %%
#checking where translagted review coulmn is null since sentiment Sentiment_Polarity Sentiment_Subjectivity are based on that
df_user_reveiw.loc[df_user_reveiw["Translated_Review"].isna()].head()

# we can check that without translated review , sentiment and sentiment polarity are rated ,which is an error , removing those columns as well
# Out:
#                                                   App Translated_Review  \
# 2                               10 Best Foods for You               NaN
# 268                                              11st               NaN
# 362                   1LINE – One Line with One Touch               NaN
# 405  2018Emoji Keyboard 😂 Emoticons Lite -sticker&gif               NaN
# 539               2Date Dating App, Love and matching               NaN
#
#     Sentiment  Sentiment_Polarity  Sentiment_Subjectivity
# 2         NaN                 NaN                     NaN
# 268   Neutral                 0.0                     0.0
# 362       NaN                 NaN                     NaN
# 405       NaN                 NaN                     NaN
# 539       NaN                 NaN                     NaN

# %%
#droping the rows whete Trnaslated values are null
df_user_reveiw.dropna(subset=["Translated_Review"],inplace=True,axis=0)

# %%
#checking null values presense after handling them
df_user_reveiw.isnull().any()
print("\n")
#checking null values presense after handling them
print("New shape for dataframe ")
df_user_reveiw.isnull().any()
# Out:
# New shape for dataframe
# App                       False
# Translated_Review         False
# Sentiment                 False
# Sentiment_Polarity        False
# Sentiment_Subjectivity    False
# dtype: bool

# %%
df_user_reveiw.shape
# Out:
# (29692, 5)

# %% [markdown]
# ### Outliers Checking

# %%
# checking for the outliers via univariate analysis
data=df_playstore.select_dtypes(exclude="object")
col=['Rating', 'Reviews', 'Size', 'Installs', 'Price']
for i in col:
  plt.figure(figsize=(12,6))
  plt.subplot(121)
  sns.histplot(data[i],kde=True)
  plt.subplot(122)
  sns.boxplot(data[i])

# %%
#checking reviews and outliers

print(df_playstore.loc[:,["Reviews","Installs"]].sort_values("Reviews").head(7))
print("\n")
print(df_playstore.loc[:,["Reviews","Installs"]].sort_values("Reviews",ascending=False).head(7))
#we can observe zero reviews as well
# df_playstore["Reviews"].value_counts().reset_index()

data=df_playstore.loc[:,["Reviews","Installs"]].sort_values("Reviews")
print(data.corr())
# Out:
#       Reviews  Installs
# 9700        0        50
# 9663        0        50
# 9662        0        10
# 9660        0        10
# 9658        0        10
# 9654        0        50
# 9653        0        10
#
#
#        Reviews    Installs
# 2544  78158306  1000000000
# 336   69119316  1000000000
# 2545  66577313  1000000000
# 335   56642847  1000000000
# 1670  44891723   100000000
# 4005  42916526   500000000
# 1654  27722264  1000000000
#            Reviews  Installs
# Reviews   1.000000  0.625158
# Installs  0.625158  1.000000

# %% [markdown]
# **Observations** - Reveiw Column
#
# *   We can check reviews varies with the sum of installs of app.
# *   Also we can observe here that Installs and reviews have +ve correlation
# *   Keeping the outliers as it is , as we don't have further information

# %%
#checking outliers in size column
print("Cheking zero size application with installed")
print(df_playstore.loc[df_playstore["Size"]==0,:]["Installs"].head())
data=df_playstore["Size"].value_counts().reset_index()
print("\n")
print("checking the size with count respectively")
data.sort_values(by="Size",ascending=False)
# Out:
# Cheking zero size application with installed
# 209      100000
# 479         100
# 1532      50000
# 1542    5000000
# 4192        500
# Name: Installs, dtype: int64
#
#
# checking the size with count respectively
#       Size  count
# 171  100.0     14
# 109   99.0     30
# 173   98.0     13
# 181   97.0     11
# 148   96.0     23
# ..     ...    ...
# 113    0.4     29
# 101    0.3     32
# 58     0.2     47
# 91     0.1     34
# 128    0.0     27
#
# [191 rows x 2 columns]

# %%
#checking outliers in size columns by 6 sigma method
mean=df_playstore["Size"].mean()
std=df_playstore["Size"].std()

outlier_pos = mean + 4*std
outlier_neg = mean - 4*std # 4 to 6 sigma
print(outlier_pos,outlier_neg)

df_playstore.loc[(df_playstore.Size>=outlier_neg) & (df_playstore.Size<=outlier_pos),].shape[0]/df_playstore.shape[0]
#we can observe upto 4sigma , 100% data points are geting covered
# Out:
# 101.70681874209926 -63.01803350163492
# 1.0

# %% [markdown]
# **Observations** - Size Column
# *   We can observe 27 zero size application might be very small in size i.e bytes and  these apps have good installs as well ,also last updated dates are bEfore 2018
# *   Good number of apps are there above  50 mb size, we can categories and check the distribution further , not dropping the outliers as of now and upto 4sigma almost 100 data is getting covered

# %%
df_playstore["Installs"].unique()
#we  can observe that huge number of app installs which are showing under outliers
# Out:
# array([     10000,     500000,    5000000,   50000000,     100000,
#             50000,    1000000,   10000000,       5000,  100000000,
#        1000000000,       1000,  500000000,         50,        100,
#               500,         10,          1,          5,          0])

# %%
df_playstore.Installs.value_counts().sort_values(ascending=False)

df_playstore.loc[df_playstore["Installs"]==0,]
# we can observe under zero isntalls , paid apps are also there
# Out:
#                                                App            Category  \
# 4465  Popsicle Launcher for Android P 9.0 launcher     PERSONALIZATION
# 5307                       Ak Parti Yardım Toplama              SOCIAL
# 5486                        AP Series Solution Pro              FAMILY
# 5945                    Ain Arabic Kids Alif Ba ta              FAMILY
# 6692                                 cronometra-br        PRODUCTIVITY
# 7434                                 Pekalongan CJ              SOCIAL
# 8081                                    CX Network            BUSINESS
# 8614                             Sweden Newspapers  NEWS_AND_MAGAZINES
# 8871                        Test Application DT 02      ART_AND_DESIGN
# 9337                      EG | Explore Folegandros    TRAVEL_AND_LOCAL
# 9719                                  EP Cook Book             MEDICAL
# 9905                                   Eu sou Rico             FINANCE
# ...

# %%
mean=df_playstore["Installs"].mean()
std=df_playstore["Installs"].std()

outlier_pos = mean + 2*std # 4 to 6 sigma
outlier_neg = mean - 2*std # 4 to 6 sigma
print(outlier_pos,outlier_neg)

df_playstore.loc[(df_playstore.Installs>=outlier_neg) & (df_playstore.Installs<=outlier_pos),].shape[0]/df_playstore.shape[0]
#we can observe upto 4sigma , 100% data points are geting covered
# Out:
# 115362809.63383833 -99790388.32019818
# 0.9954394693200663

# %%
print(df_playstore.loc[~((df_playstore.Installs>=outlier_neg) & (df_playstore.Installs<=outlier_pos)),].shape)
df_playstore.loc[~((df_playstore.Installs>=outlier_neg) & (df_playstore.Installs<=outlier_pos)),].head()

#only 44 rows are left that too we can observe with very high installs which cannot be consideted under outlier , leaving the same
# Out:
# (44, 13)
#                                           App             Category  Rating  \
# 152                         Google Play Books  BOOKS_AND_REFERENCE     3.9
# 335  Messenger – Text and Video Chat for Free        COMMUNICATION     4.0
# 336                        WhatsApp Messenger        COMMUNICATION     4.4
# 338              Google Chrome: Fast & Secure        COMMUNICATION     4.3
# 340                                     Gmail        COMMUNICATION     4.3
#
#       Reviews  Size    Installs  Type  Price Content Rating  \
# 152   1433233  12.0  1000000000  Free    0.0           Teen
# 335  56642847  12.0  1000000000  Free    0.0       Everyone
# 336  69119316  12.0  1000000000  Free    0.0       Everyone
# 338   9642995  12.0  1000000000  Free    0.0       Everyone
# 340   4604324  12.0  1000000000  Free    0.0       Everyone
#
#                 Genres Last Updated         Current Ver         Android Ver
# ...

# %% [markdown]
# Oservations Installs Column - We can observe apps with 0 installs  , 1 installs and max installs are also there , cannot be considered as outliers , as we can check , most , outiers are high installed cannot be removed , leaving the same.

# %%
print(df_playstore["Price"].unique())
print(df_playstore["Price"].max())
print(df_playstore["Price"].min())
# Out:
# [  0.     4.99   3.99   6.99   1.49   2.99   7.99   5.99   3.49   1.99
#    9.99   7.49   0.99   9.     5.49  10.    24.99  11.99  79.99  16.99
#   14.99   1.    29.99  12.99   2.49  10.99   1.5   19.99  15.99  33.99
#   74.99  39.99   3.95   4.49   1.7    8.99   2.     3.88  25.99 399.99
#   17.99 400.     3.02   1.76   4.84   4.77   1.61   2.5    1.59   6.49
#    1.29   5.    13.99 299.99 379.99  37.99  18.99 389.99  19.9    8.49
#    1.75  14.     4.85  46.99 109.99 154.99   3.08   2.59   4.8    1.96
#   19.4    3.9    4.59  15.46   3.04   4.29   2.6    3.28   4.6   28.99
#    2.95   2.9    1.97 200.    89.99   2.56  30.99   3.61 394.99   1.26
#    1.2    1.04]
# 400.0
# 0.0

# %%
#using 6 sigma method to check the outliers in price columns ,
mean=df_playstore["Price"].mean()
std=df_playstore["Price"].std()

outlier_pos = mean + 1*std # 4 to 6 sigma
outlier_neg = mean - 1*std # 4 to 6 sigma
print(outlier_pos,outlier_neg)

df_playstore.loc[(df_playstore.Price>=outlier_neg) & (df_playstore.Price<=outlier_pos),].shape[0]/df_playstore.shape[0]
#we can observe upto 1 sigma 99% data points are covered ,
# Out:
# 17.96191951319695 -15.761533941057646
# 0.9949212271973465

# %%
print(df_playstore.loc[~((df_playstore.Price>=outlier_neg) & (df_playstore.Price<=outlier_pos)),].shape)
df_playstore.loc[~((df_playstore.Price>=outlier_neg) & (df_playstore.Price<=outlier_pos)),].sort_values(by="Price",ascending =False).head()

#only 49 rows that too prices above prices from 17.99 rs , not removing the outliers as we don't have much information + these all are paid apps and with good isntalls
#will check with categorinsing the the price
# Out:
# (49, 13)
#                            App   Category  Rating  Reviews  Size  Installs  \
# 4367  I'm Rich - Trump Edition  LIFESTYLE     3.6      275   7.3     10000
# 5358                I am Rich!    FINANCE     3.8       93  22.0      1000
# 4197    most expensive app (H)     FAMILY     4.3        6   1.5       100
# 5373        I AM RICH PRO PLUS    FINANCE     4.0       36  41.0      1000
# 5369                 I am Rich    FINANCE     4.3      180   3.8      5000
#
#       Type   Price Content Rating         Genres Last Updated Current Ver  \
# 4367  Paid  400.00       Everyone      Lifestyle   2018-05-03       1.0.1
# 5358  Paid  399.99       Everyone        Finance   2017-12-11         1.0
# 4197  Paid  399.99       Everyone  Entertainment   2018-07-16         1.0
# 5373  Paid  399.99       Everyone        Finance   2018-06-25       1.0.2
# 5369  Paid  399.99       Everyone        Finance   2018-03-22         1.0
#
#      Android Ver
# 4367  4.1 and up
# 5358  4.1 and up
# ...

# %% [markdown]
# Observations - Price Column
# We can observe prices max upto 400 and in good numbers , we cannot drop the same outliers as don’t have enough data , leaving the same

# %%
# Outlier checking in user-review data set

fig,ax=plt.subplots(1,2,figsize=(12,7))

sns.boxplot(df_user_reveiw["Sentiment_Subjectivity"],ax=ax[0])
ax[0].set_title("Sentiment Subjectivity Outlier Checking")
sns.boxplot(df_user_reveiw["Sentiment_Polarity"],ax=ax[1])
ax[1].set_title("Sentiment_Polarity Outlier Checking")
# Out:
# Text(0.5, 1.0, 'Sentiment_Polarity Outlier Checking')

# %%
#using 6 sigma method to check the outliers in price columns ,
mean=df_user_reveiw["Sentiment_Polarity"].mean()
std=df_user_reveiw["Sentiment_Polarity"].std()

outlier_pos = mean + 4*std
outlier_neg = mean - 4*std
print(outlier_pos,outlier_neg)

df_user_reveiw.loc[(df_user_reveiw.Sentiment_Polarity>=outlier_neg) & (df_user_reveiw.Sentiment_Polarity<=outlier_pos),].shape[0]/df_user_reveiw.shape[0]

# we can observe here that upto 4 standard deviation all points are covered , so leaveing the outliers as it is
# Out:
# 1.6116424187860752 -1.2339063806041943
# 1.0

# %%
print(df_user_reveiw.loc[~((df_user_reveiw.Sentiment_Polarity>=outlier_neg) & (df_user_reveiw.Sentiment_Polarity<=outlier_pos)),].shape)
df_user_reveiw.loc[~((df_user_reveiw.Sentiment_Polarity>=outlier_neg) & (df_user_reveiw.Sentiment_Polarity<=outlier_pos)),].sort_values(by="Sentiment_Polarity",ascending =False).head()
# Out:
# (0, 5)
# Empty DataFrame
# Columns: [App, Translated_Review, Sentiment, Sentiment_Polarity, Sentiment_Subjectivity]
# Index: []

# %% [markdown]
# Observations - We can check there is not outlier in Sentiment _Subjectivity column and Sentiment Polarity have outliers , not droping the same ,since we dont have enough information on outliers.

# %% [markdown]
# ### Merging both the dataframes Playstore + User Review

# %%
#Lets merge both both data frames and check

merge_data=pd.merge(df_playstore,df_user_reveiw,how="inner",left_on="App",right_on="App")

# %%
#checking null values in merged data frame
sns.heatmap(merge_data.isna(),cbar=False)

#No null found in merged data frame
# Out:
# <Axes: >

# %%
merge_data.describe()
# Out:
#              Rating       Reviews          Size      Installs         Price  \
# count  28250.000000  2.825000e+04  28250.000000  2.825000e+04  28250.000000
# mean       4.290577  1.184521e+06     22.861515  3.276183e+07      0.103733
# min        2.600000  1.140000e+02      0.000000  1.000000e+03      0.000000
# 25%        4.100000  8.722000e+03     12.000000  1.000000e+06      0.000000
# 50%        4.300000  5.151700e+04     12.000000  5.000000e+06      0.000000
# 75%        4.500000  3.100660e+05     27.000000  1.000000e+07      0.000000
# max        4.900000  7.815831e+07     99.000000  1.000000e+09     29.990000
# std        0.309401  5.927353e+06     22.506211  1.249328e+08      1.344401
#
#                         Last Updated  Sentiment_Polarity  \
# count                          28250        28250.000000
# mean   2018-03-17 17:52:10.534513408            0.188273
# min              2011-06-29 00:00:00           -1.000000
# ...

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# **Following are the manipulations done to clean the data frame :-**
# * ***Playstore Data Frame-***
#     * Droped 1 row (outlier) having rating above 5 ,as rating should be in the 0-5 as per data.
#     * Filled the null values in rating column with median as there are outier present in the column and data is skewed towards left.
#     * Dropped rows from("Type","Content Rating",'Current Ver',"Android Ver") containing null values as null values were very less even less than 0.1%.
#     * Reviews data set converted to integer and Last Updated data converted to date time for further analysis.
#     * Converted the size column  which is mix of KB and MB to MB and and imputed the "Varies with device" (size) option with median .
#     * Converted Installs column to numeric.
#     * Converted price column to numeric (float).
#     * Checked outliers using 6 sigma method , but not droped the same , as we have not enough information about the outliers.
# * ***User Review DataFrame-***
#     * Dropped rows where Transelated reviews values were null  since sentiment Sentiment_Polarity Sentiment_Subjectivity are based on that.
#
# * ***Merged DataFrame*** - Created a new data frame merging both the data dframes and no null values found in the same.

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# #### Chart - 1- Category of Apps (Univariate)

# %%
# Chart - 1 visualization code
#barplot
plt.figure(figsize=(10,8))
x=df_playstore.Category.value_counts().index
y=df_playstore.Category.value_counts().values
sns.barplot(x=y,y=x,palette="bright")
plt.xlabel("Total_Number_of Apps")
plt.ylabel("Category")
plt.title("Category of Apps")
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-382-c67f26fd6f71>:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=y,y=x,palette="bright")

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Bar charts are ideal for comparing different categories and can display a wide range of data types, from numerical to categorical.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# We can observe here that Family,Games,Tools,Buisness and Medical are top five category of apps in playstore and Beauty , Comics,Parenting, Art and designs are the bottom in list.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, we can observe majority of apps are falling under Family,Games,Tools,Buisness and Medical category and can be considered to deveolp the apps under these categories.
#
# Also we need to check the reason of this huge difference between the top 5 and bottom 5 category apps in playstore. Maximum user Installs might be reason , lets further analyse.

# %% [markdown]
# #### Chart -2 - Category vs Installs (Bivariate)

# %%
# Chart - 2 visualization code
data=df_playstore.groupby(["Category"] )["Installs"].sum().reset_index().sort_values(by=["Installs"],ascending=False)
print("\t\t\t\tTop 5 Categories with most Installs")
print(data.head())

plt.figure(figsize=(10,8))
x=data["Category"]
y=data["Installs"]
sns.barplot(x=y,y=x,palette="plasma")
plt.title("Category vs Install")
plt.xlabel("Sum of Installs")
# Out:
# 				Top 5 Categories with most Installs
#          Category     Installs
# 14           GAME  13878924415
# 6   COMMUNICATION  11038276251
# 29          TOOLS   8001271905
# 25   PRODUCTIVITY   5793091369
# 27         SOCIAL   5487867902
# <ipython-input-383-2ece8818d108>:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=y,y=x,palette="plasma")
# Text(0.5, 0, 'Sum of Installs')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Bar charts are ideal for comparing different categories and can display a wide range of data types, from numerical to categorical.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# We can observe here that Games , Communication , Tools , Productivity, and Social are the most installed app category. Event ,Beauty Partenting, Medical and Comics are the 5 bottom category least installed apps

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# As per the above plots , developer can consider Game , Communication , Tools, Productivty and Social category apps to introduce in the android market for positive response.
#
# Also checked in above two chart Games , Tools and Productivity were common in most installed category, which is the reason for majority apps under top 5 category in play store. Need to further analyse and check for price or revenue.

# %% [markdown]
# #### Chart - 3 Category Vs Ratings/Reviews(Bivariate)

# %%
# Chart - 3 visualization code
df=df_playstore.copy()
print(f"Maxium Rating {df_playstore.Rating.max()} and Minimum Rating is {df_playstore.Rating.min()}")

#function to categories Rating column to Good(4 and above) Average(3-4) and Poor(1-3)
def Rating(n):
  if n>=1 and n<3:
    return "Poor"
  elif n>=3 and n<4:
    return "Average"
  else:
    return "Good"

df["Cat_Rating"]=df["Rating"].apply(Rating)
df.head(1)
# Out:
# Maxium Rating 5.0 and Minimum Rating is 1.0
#                                               App        Category  Rating  \
# 0  Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
#
#    Reviews  Size  Installs  Type  Price Content Rating        Genres  \
# 0      159  19.0     10000  Free    0.0       Everyone  Art & Design
#
#   Last Updated Current Ver   Android Ver Cat_Rating
# 0   2018-01-07       1.0.0  4.0.3 and up       Good

# %%
#using cross tab to know the count of good ,average and poor ratings respectively
good=pd.crosstab(df["Category"],df["Cat_Rating"]).reset_index().sort_values(by="Good",ascending= False)
Poor=pd.crosstab(df["Category"],df["Cat_Rating"]).reset_index().sort_values(by="Poor",ascending= False)
average=pd.crosstab(df["Category"],df["Cat_Rating"]).reset_index().sort_values(by="Average",ascending= False)

# %%
fig,axes=plt.subplots(1,3,figsize=(20,6))

#ploting Category vs Good Rating
sns.barplot(y=good["Category"],x=good["Good"],palette="plasma",ax=axes[0])
axes[0].set_title("Category vs Rating(Good)")

#ploting Category vs Poor Rating
sns.barplot(y=Poor["Category"],x=Poor["Poor"],ax=axes[1],palette="RdGy")
axes[1].set_title("Category vs Rating(Poor)")

#ploting Category vs Average Rating
sns.barplot(y=average["Category"],x=average["Average"],ax=axes[2],palette="PuOr")
axes[2].set_title("Category vs Rating(Average)")
plt.tight_layout()
# Out:
# <ipython-input-386-6bb5f77bec28>:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(y=good["Category"],x=good["Good"],palette="plasma",ax=axes[0])
# <ipython-input-386-6bb5f77bec28>:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(y=Poor["Category"],x=Poor["Poor"],ax=axes[1],palette="RdGy")
# <ipython-input-386-6bb5f77bec28>:12: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(y=average["Category"],x=average["Average"],ax=axes[2],palette="PuOr")

# %%
# Ploting Reviews vs Category
df=df_playstore.groupby("Category")["Reviews"].sum().reset_index().sort_values("Reviews",ascending=False)
plt.figure(figsize=(11,7))
sns.barplot(y=df["Category"],x=df["Reviews"],palette="pastel")
plt.title("Category Vs Total Reviews")
plt.ylabel("Total Number of Reviews")
plt.tight_layout()
# Out:
# <ipython-input-387-6e09ffba2588>:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(y=df["Category"],x=df["Reviews"],palette="pastel")

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Bar charts are ideal for comparing different categories and can display a wide range of data types, from numerical to categorical.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * We can observe in category vs rating chart -Family , Game , Tool ,Buisness , Personalisation are top 5 category with most Good Ratings.
# * Tools , Family ,Lifestyle Finance category have received most Poor Rating.
# * Game , Communication, Tools, Social , Family category apps are most reviewd.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Considering both reviews and ratings - Family ,Tools , Games , Communication, Buisness category should be prefred for developing app.

# %% [markdown]
# #### Chart - 4 -Ratings and Reviews vs Updated year (Bivariate)

# %%
# Chart - 4 visualization code
year=df_playstore.copy()
#retreiving the year
year["Updated_Year"]=year["Last Updated"].dt.year
fig,axes=plt.subplots(1,2,figsize=(12,6))
dyear=year.groupby("Updated_Year")["Reviews"].sum().reset_index().sort_values("Reviews")
sns.lineplot(x="Updated_Year",y="Reviews",data=dyear,ax=axes[0],color="red",marker="o")
axes[0].set_title("Total Reviews over the Updated Year")

year=year.groupby("Updated_Year")["Rating"].mean().reset_index().sort_values("Rating")
sns.lineplot(x="Updated_Year",y="Rating",data=year,ax=axes[1],marker="o")
axes[1].set_title("Average Ratings over the Updated Year")
plt.tight_layout()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Line plot is used to show the trend over the time and here trend is shown over the updated year

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * We can observe gradual increase in reviews from 2013 -2016 and high peak of reviews over the year 2017-2018.
# * We can observe here that average ratings are increasing after over the updated year.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Timely Updates needs to be rolled out to improve the performance of the app and to keep the consumer engaged, leading to improvement in Average rating and Review count of the app.

# %% [markdown]
# #### Chart -5 Type (Univariate)

# %%
# Chart - 5 visualization code
x = list(df_playstore["Type"].value_counts())
y = list(df_playstore["Type"].value_counts().index)

#pie chart (Type-Paid vs Free)
plt.figure(figsize=(15, 7))
plt.subplot(121)
plt.pie(x, labels=y, autopct='%1.1f%%',explode=[0,0],startangle=90,colors=['skyblue','red'],shadow=True)
plt.title("%Apps in Playstore - Free or Paid")

#pie chart (Type wise Installed%)
plt.subplot(122)
plt.pie(df_playstore.groupby("Type")["Installs"].sum().reset_index()["Installs"], labels=y, autopct='%1.1f%%',explode=[0,0],startangle=90,colors=['skyblue','red'],shadow=True)
plt.title("%Installed Apps -Free or Paid")
plt.tight_layout()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Pie chart is a type of graph in which a circle is divided into sectors that each represents a proportion of the whole. Here it represent the % of apps availability i.e Free or Paid and consumer installs.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# We can observe here that , 99.9% Free apps are installed by the conumer and so is the reason of 92.2% app Free app availability in the play store.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Developing Free apps is suggested for the positive response and revenue for the organisation as the same is highly prefered and installed by the users.

# %% [markdown]
# #### Chart - 6 Type vs Installs (Bivariate)

# %%
# Chart - 6 visualization code
#checking type vs installs
data_installs=df_playstore.groupby(["Type","Category"]).agg({"Installs":"sum"}).reset_index().sort_values(by="Installs",ascending=False)
print(f"\t\t\tTop-5 Apps Category of type Free which are mostly installed by consumer")
print("\n")
print(data_installs.loc[data_installs["Type"]=="Free"].head(5))
print("\n")
print("*"*100)
print(f"\t\t\tTop-5 Apps Category of type Paid which are mostly installed by consumer")
print("\n")
print(data_installs.loc[data_installs["Type"]=="Paid"].head(5))
# Out:
# 			Top-5 Apps Category of type Free which are mostly installed by consumer
#
#
#     Type       Category     Installs
# 14  Free           GAME  13857924450
# 6   Free  COMMUNICATION  11036916201
# 29  Free          TOOLS   7999544474
# 25  Free   PRODUCTIVITY   5791679314
# 27  Free         SOCIAL   5487861902
#
#
# ****************************************************************************************************
# 			Top-5 Apps Category of type Paid which are mostly installed by consumer
#
#
#     Type         Category  Installs
# 45  Paid             GAME  20999965
# 42  Paid           FAMILY  20599814
# 53  Paid  PERSONALIZATION   3257794
# 54  Paid      PHOTOGRAPHY   1878740
# 59  Paid            TOOLS   1727431

# %%
#Filtering free and Paid category installs and ploting
free=data_installs.loc[data_installs["Type"]=="Free"].head(5)
paid=data_installs.loc[data_installs["Type"]=="Paid"].head(5)
fig,axes=plt.subplots(1,2,figsize=(15,6)) #fig, axes = plt.subplots(2, 2, figsize=(12, 10))

sns.barplot(x=free['Category'], y=free['Installs'], ax=axes[0],palette="inferno")
axes[0].set_title('Top 5 Free Category Installs')


sns.barplot(x=paid['Category'], y=paid['Installs'], ax=axes[1],palette="viridis")
axes[1].set_title("Top 5 Paid Category Installs")
plt.tight_layout()
# Out:
# <ipython-input-391-1603b8bf7fb8>:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=free['Category'], y=free['Installs'], ax=axes[0],palette="inferno")
# <ipython-input-391-1603b8bf7fb8>:10: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=paid['Category'], y=paid['Installs'], ax=axes[1],palette="viridis")

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Bar charts are ideal for comparing different categories and can display a wide range of data types, from numerical to categorical.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * We can observe here that under Free section - Game , Communication , Tools , Productivity and Social Category apps are most Installed by the consumers.
#
# * Under Paid section - Game , Family ,Personalisation ,photography , Tools category are the most installed by the conusmers.
#
# * We can observe Game category is common under paid and free section and with highest installed in both free and paid Category.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Developing app under free section and category -Game ,Communication, Tools, Productivity,Social must be considered , keeping in mind the number of downloads. Need to analyse Generes under above mentioned categories

# %% [markdown]
# #### Chart - 7- Most Installed Apps (Bivariate)

# %%
# Chart - 7 visualization code
#Most installed apps
plt.figure(figsize=(10,5))
app=df_playstore.loc[:,["App","Installs"]].sort_values("Installs",ascending=False).head(10)
sns.barplot(x=app["Installs"],y=app["App"],palette="pastel")
plt.title("Top 10 Most Installed Apps")
# Out:
# <ipython-input-392-d0ed35f49f73>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=app["Installs"],y=app["App"],palette="pastel")
# Text(0.5, 1.0, 'Top 10 Most Installed Apps')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Bar charts are ideal for comparing different categories and can display a wide range of data types, from numerical to categorical.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Google News, Maps ,Google Street View, Youtube, Google play movies, Google+ , Instagram, Facebook, Google, Google Play books are the top 10 Installed apps.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Google apps are majority in most downloaded category.

# %% [markdown]
# #### Chart - 8 Genres vs Installs (Bivariate)

# %%
# Chart - 8 visualization code
genre= df_playstore.groupby(["Genres","Type"])["Installs"].sum().reset_index()

genre_free=genre.loc[genre["Type"]=="Free",].sort_values("Installs",ascending =False).head(5)

genre_paid=genre.loc[genre["Type"]=="Paid",].sort_values("Installs",ascending =False).head(5)

fig,ax=plt.subplots(1,2,figsize=(18,6))

sns.barplot(x=genre_free["Genres"],y=genre_free["Installs"],ax=ax[0],palette="magma")
ax[0].set_title("Top 5 Free Genres with most Installs")

sns.barplot(x=genre_paid["Genres"],y=genre_paid["Installs"],ax=ax[1],palette="cividis")
ax[1].set_title("Top 5 Paid Genres with most Installs")
plt.tight_layout()
# Out:
# <ipython-input-393-bbb050238d78>:10: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=genre_free["Genres"],y=genre_free["Installs"],ax=ax[0],palette="magma")
# <ipython-input-393-bbb050238d78>:13: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=genre_paid["Genres"],y=genre_paid["Installs"],ax=ax[1],palette="cividis")

# %%
#filtering out the top 5 categories (Game ,Communication, Tools, Productivity,Social) with highest downloads under free section
df=df_playstore.loc[(df_playstore["Category"]=="GAME" )]
free=df.loc[df["Type"]=="Free",]
free=free.groupby("Genres")["Installs"].sum().reset_index().sort_values("Installs",ascending=False).head()
paid=df.loc[df["Type"]=="Paid",]
paid=paid.groupby("Genres")["Installs"].sum().reset_index().sort_values("Installs",ascending=False).head()
fig,ax=plt.subplots(1,2,figsize=(12,6))
sns.barplot(x=free["Genres"],y=free["Installs"],ax=ax[0],palette="bright")
ax[0].set_title("Top 5 Downloads Genre(Game)-Free ")
sns.barplot(x=paid["Genres"],y=paid["Installs"],ax=ax[1],palette="pastel")
ax[1].set_title("Top 5 Downloads Genre(Game)-Paid")

plt.tight_layout()
# Out:
# <ipython-input-394-61e8a7275bd1>:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=free["Genres"],y=free["Installs"],ax=ax[0],palette="bright")
# <ipython-input-394-61e8a7275bd1>:10: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=paid["Genres"],y=paid["Installs"],ax=ax[1],palette="pastel")

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Bar charts are ideal for comparing different categories and can display a wide range of data types, from numerical to categorical.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * We can observe here that Communication ,Tools, Productivity , Social,Photography are the top 5 Genre under free section with maximum downloads.
# * Action ,Arcade Action and Adventure ,Personalisation , Puzzle, Role Playing are the top 5 Genre under paid section with maximum downloads.
# * Under most downloaded category Games - Arcade, Action, Casual, Racing and Puzzel are most downloaded genres.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Considering the downloads , Genres under (Communication ,Tools, Productivity , Social,Photography) free section should be considered.

# %% [markdown]
# #### Chart - 9 Installed vs Content Rating (Bivariate)

# %%
# Chart - 9 visualization code
df_playstore.groupby(["Content Rating"]).agg({"Installs":"sum"}).reset_index().sort_values(by="Installs",ascending=False)
# pie chart to check the %of Installed based on Content Rating
x=df_playstore.groupby(["Content Rating"]).agg({"Installs":"sum"}).reset_index().sort_values(by="Installs",ascending=False)["Installs"]
y=df_playstore.groupby(["Content Rating"]).agg({"Installs":"sum"}).reset_index().sort_values(by="Installs",ascending=False)["Content Rating"]
fig,ax =plt.subplots(figsize=(15,9))
colors=['gold', 'yellowgreen', 'lightcoral', 'lightskyblue', 'lightgreen', 'lightpink',"green"]
ax.pie(x, labels=y, autopct='%1.1f%%',startangle=140,explode= [0,0,0,0,0,0.19],colors=colors,shadow=True)
plt.title("%Installed Apps by Content Rating ")
# Out:
# Text(0.5, 1.0, '%Installed Apps by Content Rating ')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A pie chart expresses a part-to-whole relationship and area covered in a circle with different colors.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# We can observe here that Everyone age group have installed 69.5% of apps and Teen age group have installed 21.9% of apps.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Everyone(Content Rating) should be the first prioty and second Teen (Content Rating)  also be considered for app developing. Rest age groups are having less installs and same should not be considered.

# %% [markdown]
# #### Chart - 10- Android versions vs Total Installs (Bivariate)

# %%
# Chart - 10 visualization code
df_playstore.groupby("Android Ver").agg({"Installs":["sum"]}).reset_index().sort_values(by=[("Installs","sum")],ascending=False).head()
#We can observe clearly that Android ver "Varies with device" is more downloaded ,rest not clear , creating group to analyze better
# Out:
#            Android Ver     Installs
#                                 sum
# 32  Varies with device  39079618782
# 17          4.1 and up  12819137789
# 13          4.0 and up   5754016206
# 15        4.0.3 and up   5117481683
# 20          4.4 and up   4942579498

# %%
#creating a copy of data frame
copy_playstore=df_playstore.copy()

#function for to take out only first word from string
def version(n):
  n=n.split()
  n=n[0]
  return n[0]

#using apply method with function
copy_playstore["Android Ver"]=copy_playstore["Android Ver"].apply(version)


#function to convert elements into groups for further analysis
def version_checks(n):
  if n in "5768":
    n="4"
    return n
  elif n in "123":
    n="3"
    return n
  else:
    return n

#using apply method with function
copy_playstore["Android Ver"]=copy_playstore["Android Ver"].apply(version_checks)


#considering 4 as Android version 4 and above , 3 as  Android version 3 and below , V as  Android version Varies with device

# %%
df=copy_playstore.groupby("Android Ver")["Installs"].sum().reset_index().sort_values(by="Installs",ascending=False)

#fucntion to make Android version data more readable
def change(n):
  if n == "V":
    n= "Varies with Device"
    return n
  elif n == "4":
    n= "4 and Up"
    return n
  else:
    n= "3 and Below"
    return n

df["Android Ver"]=df["Android Ver"].apply(change)

df
#we can check more downloads are there for apps having android versio  varies with device and same can be considered for developing
#second option is android atleaset above 4 version
# Out:
#           Android Ver     Installs
# 2  Varies with Device  39079618782
# 1            4 and Up  32709000026
# 0         3 and Below   3332741609

# %%
#ploting
x=list(df["Installs"])
y=list(df["Android Ver"])
plt.figure(figsize=(15, 7))
plt.pie(x, labels=y, autopct='%1.1f%%',startangle=90,colors=['skyblue',"#98df8a","#d62728"],shadow=True)
plt.title("Android Versoion -Total Installs")
# Out:
# Text(0.5, 1.0, 'Android Versoion -Total Installs')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A pie chart expresses a part-to-whole relationship and area covered in a circle with different colors.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# We can observe here after grouping the Android version ,  52% apps are installed under varies with device android version and 43.5% aaps are installed under android version 4 and above. Conumers are preferring varies with device Android version more.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Varies with Device (Android Version) can be considered on first priority for app development and second option is Android version 4 and above.

# %% [markdown]
# #### Chart - 11 - Price vs Installs (Bivariate)

# %%
# Chart - 11 visualization code
#lets check the installs category wise in paid version
def grouping(n):
  if n < 10:
    n=" <10$"
    return n
  elif n>=10 and n<50:
    n= "10-50 $"
    return n
  elif n>=50 and n<100:
    n="50-100 $"
    return n
  elif n>=100 and n<200:
    n="100-200 $"
    return n
  elif n>=200 and n<300:
    n="200-300 $"
    return n
  elif n>=300 and n<400:
     n="300-400 $"
     return n
  elif n>=400:
    n = " >400$"
    return n
#filtering data as Paid before grouping
price_grouping=df_playstore.loc[df_playstore["Type"]=="Paid",]

price_grouping["Price"]=price_grouping["Price"].apply(grouping)
price_grouping.head(1)
# Out:
# <ipython-input-400-bfab7cfd01bd>:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   price_grouping["Price"]=price_grouping["Price"].apply(grouping)
#                                                App  Category  Rating  Reviews  \
# 234  TurboScan: scan documents and receipts in PDF  BUSINESS     4.7    11442
#
#      Size  Installs  Type  Price Content Rating    Genres Last Updated  \
# 234   6.8    100000  Paid   <10$       Everyone  Business   2018-03-25
#
#     Current Ver Android Ver
# 234       1.5.2  4.0 and up

# %%
df=price_grouping.groupby(["Category","Price"]).agg({"Installs":["sum"]}).reset_index().sort_values(by=[("Installs","sum")],ascending=False)
df=price_grouping.groupby("Price")["Installs"].sum().reset_index().sort_values("Installs",ascending=False)
# ploting
sns.barplot(x=df["Price"],y=df["Installs"],palette="bright")
plt.title("Price vs Installs")
plt.ylabel("Sum of Installs ")
# Out:
# <ipython-input-401-d5d2b4e5364e>:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=df["Price"],y=df["Installs"],palette="bright")
# Text(0, 0.5, 'Sum of Installs ')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Bar charts are ideal for comparing different categories and can display a wide range of data types, from numerical to categorical.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# We can observe here that under paid section , maximum downloads are for apps of price less than 10$.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# For paid apps , price can be introduced below 10$ for positive response from consumer and keeping in mind the maximum downloads

# %% [markdown]
# #### Chart - 12 Content Rating vs Installs(Bivariate)

# %%
# Chart - 12 visualization code
#paid section most download content rating wise

df=price_grouping.groupby(["Content Rating","Price"])["Installs"].sum().reset_index().sort_values(by="Installs",ascending=False).head()
plt.figure(figsize=(14,6))
i=df["Installs"]
j=df["Content Rating"]
plt.pie(i, labels=j, autopct='%1.1f%%',startangle=90,explode = (0,0,0,0,0) ,colors=['#08306b', '#08519c', '#2171b5', '#4292c6', '#6baed6', '#9ecae1', '#c6dbef'] ,shadow=True)
plt.title("%Content Rating based on most download under paid section")
plt.tight_layout()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A pie chart expresses a part-to-whole relationship and area covered in a circle with different colors.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# We can observe here that under paid top most downloads are of below 10$ category and age group of highest installs is Everyone from top 5 content rating.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Under paid section , content rating to be considered is Everyone , that too under 10$ price range , considering the highest number of installs.

# %% [markdown]
# #### Chart - 13 - Size vs Installs vs Type (Multivariate)

# %%
# Chart - 13 visualization code
#fucntion to group by size categories
def group(n):
    if n < 10:
        return "<10"
    elif n >= 10 and n < 20:
        return "10-19"
    elif n >= 20 and n < 30:
        return "20-29"
    elif n >= 30 and n < 40:
        return "30-39"
    elif n >= 40 and n < 50:
        return "40-49"
    elif n >= 50 and n < 60:
        return "50-59"
    elif n >= 60 and n < 70:
        return "60-69"
    elif n >= 70 and n < 80:
        return "70-79"
    elif n >= 80 and n < 90:
        return "80-89"
    elif n >= 90 and n <= 100:
        return "90-100"
    else:
        return n

size =df_playstore.copy()
size["size_group"]=size["Size"].apply(group)
check=size.groupby(["size_group","Type","Category"])["Installs"].sum().reset_index().sort_values("Installs",ascending=False)
#ploting bar plot
plt.figure(figsize=(10,8))
x=check["size_group"]
y=check["Installs"]
scaled=[x/1000000 for x in y]
sns.barplot(x=x,y=y,data=check, palette="bright",hue="Type")
plt.title("Total Number of Installs based on Size (MB)")
plt.xlabel("Size in MB")
plt.legend()
plt.tight_layout()

# %%
#ploting paid section separately for better clarity
size =df_playstore.copy()
size["size_group"]=size["Size"].apply(group)
check=size.groupby(["size_group","Type","Category"])["Installs"].sum().reset_index().sort_values("Installs",ascending=False)

check2=check.loc[check["Type"]=="Paid",].sort_values("Installs",ascending=False)

plt.figure(figsize=(10,8))
x=check2["size_group"]
y=check2["Installs"]
sns.barplot(x=x,y=y,data=check, palette="bright",hue="Type")
plt.title("Total Number of Paid Installs based on Size (MB)")
plt.xlabel("Size in MB")
plt.tight_layout()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Bar charts are ideal for comparing different categories and can display a wide range of data types, from numerical to categorical.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * We can observe here free apps that too  between 10-19 mb size are mostly prefered by consumer.
# * Paid apps of size between 90-100 MB, 20-29 MB and 10-19 MB are most downloaded by the consumer

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# It is suggested to develop apps of size starting from 10-19 mb under free section and same is most installed by consumer and under paid section 90-100 MB and 20-29 Mb apps are most dowloaded.

# %% [markdown]
# #### Chart - 14 - Size Group vs Reviews and Rating (Bivariate)

# %%
# Chart - 14 visualization code

rating = size.groupby("size_group")["Rating"].mean().reset_index().sort_values("Rating",ascending =False)
review=size.groupby("size_group")["Reviews"].sum().reset_index().sort_values("Reviews",ascending =False)

fig, ax= plt.subplots(1,2,figsize=(12,6))

sns.barplot(x=rating["size_group"],y=rating["Rating"],ax=ax[0],palette="magma")
sns.barplot(x=review["size_group"],y=review["Reviews"],ax=ax[1],palette="inferno")
plt.tight_layout()
# Out:
# <ipython-input-405-1ec28cc426ea>:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=rating["size_group"],y=rating["Rating"],ax=ax[0],palette="magma")
# <ipython-input-405-1ec28cc426ea>:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=review["size_group"],y=review["Reviews"],ax=ax[1],palette="inferno")

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Bar charts are ideal for comparing different categories and can display a wide range of data types, from numerical to categorical.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# We can observe here that,10-19 MB size category have average rating 4.22 and lower in comparison with other categories ,however maximum reveiew counts cannot be ignored.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# 10-19 Mb application size should be considered for app development , since it is having maximum downloads , good average rating and most reviewd section.

# %% [markdown]
# #### Chart - 15 Revenue Generated vs Category,Genre (Bivariate)

# %%
# Chart - 15 visualization code
#considering Price for single Download , let check which category app is more generating revenue
revenue = df_playstore.loc[df_playstore["Type"]=="Paid",]
revenue["Revenue"]=revenue["Installs"]*revenue["Price"]

fig, axes = plt.subplots(2, 2, figsize=(12, 10))
# we can observe that among paid apps , most revenue generating category apps are Family , Lifestyle , Game , Finnance , Photography
df=revenue.groupby("Category")["Revenue"].sum().reset_index().sort_values(by="Revenue",ascending=False).head()
x=df["Revenue"]
y=df["Category"]
axes[0,0].pie(x, labels=y, autopct='%1.1f%%',startangle=90,explode = (0,0,0,0,0) ,colors=['skyblue','red',"green","yellow","grey","black","orange"],shadow=True)
axes[0,0].set_title("Top 5 Revenue Genrated Category")


#top 5 evenue genrated paid apps
df=revenue.groupby("App")["Revenue"].sum().reset_index().sort_values(by="Revenue",ascending=False).head()
x=df["Revenue"]
y=df["App"]
axes[0,1].pie(x, labels=y, autopct='%1.1f%%',startangle=90,explode = (0,0,0,0,0) ,colors=['skyblue','red',"green","yellow","grey","black","orange"],shadow=True)
axes[0,1].set_title("Top 5 Revenue Generated apps")

#top 5 category +genre -revenue
df=revenue.groupby(["Genres"])["Revenue"].sum().reset_index().sort_values(by="Revenue",ascending=False).head()
x=df["Revenue"]
y=df["Genres"]
axes[1,0].pie(x, labels=y, autopct='%1.1f%%',startangle=90,explode = (0,0,0,0,0) ,colors=['skyblue','red',"green","yellow","grey","black","orange"],shadow=True)
axes[1,0].set_title("Top 5 Revenue Generated Genres")
# Hideing the last subplot
axes[1, 1].axis('off')
# Out:
# <ipython-input-406-386bc5fd2f88>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   revenue["Revenue"]=revenue["Installs"]*revenue["Price"]
# (0.0, 1.0, 0.0, 1.0)

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A pie chart expresses a part-to-whole relationship and area covered in a circle with different colors.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# - Fig 1 we can observe that most revenue generated categories are Family , Lifestyle and Game.
# * Fig 2 - Top 5 revenue Generated Apps are Minecraft, Iam rich,I am rich premium, Hitman sniper and GTA Sanandreas
# * Fig 3-  shows the genre of apps ,that generated maximum revenue are Arcade and Action ,Lifestyle, Action ,Finance and role playing

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Above are the paid categories(Family , Lifestyle , Action) , genres (Arcade, Action and Adventure ,Lifestyle) and apps which have already already genrated revenue respectively , same can be considered before developing paid apps.

# %% [markdown]
# #### Chart - 16 Sentiment (Univariate)

# %%
# Chart - 16 visualization code
#checking user review data frame

#cheking the overall sentiment of the user
data_sentiment=df_user_reveiw["Sentiment"].value_counts().reset_index()


x = list(data_sentiment["count"])
y = list(data_sentiment["Sentiment"].value_counts().index)
# ploting pie chart
plt.figure(figsize=(12, 5))
plt.pie(x, labels=y, autopct='%1.1f%%',startangle=90,colors=['#2ca02c','#ff7f0e', '#1f77b4'] ,shadow=True)
plt.title("Sentiment %")

plt.tight_layout()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A pie chart expresses a part-to-whole relationship and area covered in a circle with different colors.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# We can observe here that Overall sentiment is 64% is positive, 21.3% is negative and 17.4% neutral.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Sentiments are very important factor to be considered and same will directly diretly affect the installs and let us analyse further for better conclusion

# %% [markdown]
# #### Chart -17 Apps Vs Sentiment (Bivariate)

# %%
# Chart - 17 visualization code
#creating a data frame using crosstab to check +ve -ves and nuteral ratings of each app for further analysis
app_positive_rating=pd.crosstab(df_user_reveiw.App,df_user_reveiw.Sentiment ).reset_index()

df=app_positive_rating.loc[:,["App","Positive"]].sort_values(by="Positive",ascending=False).head(5)
df
#we can observe the top 5 +ve sentiment  apps below
# Out:
# Sentiment                           App  Positive
# 378             ColorNote Notepad Notes        91
# 327            Calorie Counter - Macros        87
# 583        Family Locator - GPS Tracker        85
# 329        Calorie Counter - MyNetDiary        82
# 24         8fit Workouts & Meal Planner        82

# %%
#checking top -ve rating apps
df1=app_positive_rating.loc[:,["App","Negative"]].sort_values(by="Negative",ascending=False).head(5)
df1
#we can observe the top 5 +ve rating apps below observe the most -negative sentiment apps belwo
# Out:
# Sentiment                    App  Negative
# 114          Angry Birds Classic        59
# 209          Be A Legend: Soccer        59
# 571                     Facebook        59
# 395                Cooking Fever        57
# 335        Candy Crush Soda Saga        50

# %%
#ploting
fig,axes=plt.subplots(1,2,figsize=(15,6))
sns.barplot(x=df['Positive'] ,y=df['App'], ax=axes[0],palette="bright")
axes[0].set_title('Top 5 +ve Sentiment Apps')


sns.barplot(x=df1['App'], y=df1['Negative'], ax=axes[1],palette="pastel")
plt.xticks(rotation=45)
axes[1].set_title("Top 5 -ve Sentiment Apps")
# Out:
# <ipython-input-410-1856f9624325>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=df['Positive'] ,y=df['App'], ax=axes[0],palette="bright")
# <ipython-input-410-1856f9624325>:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=df1['App'], y=df1['Negative'], ax=axes[1],palette="pastel")
# Text(0.5, 1.0, 'Top 5 -ve Sentiment Apps')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Bar charts are ideal for comparing different categories and can display a wide range of data types, from numerical to categorical.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# ColorNote Notepad Notes, Calorie Counter-Macros, Family Locator - GPS Tracker, Calorie Counter - MyNetDiary, 8fit Workouts & Meal Planner are the top 5 most +ve sentiment apps.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Sentiment analysis is very important to consider before developing apps

# %% [markdown]
# #### Chart - 18 Sentiment vs Category ,Content (Bivariate)

# %%
# Chart - 18 visualization code
#checking sentiments for category
df=pd.crosstab(merge_data.Category,merge_data.Sentiment).reset_index().sort_values("Positive",ascending=False).head()
df
df1=pd.crosstab(merge_data.Category,merge_data.Sentiment).reset_index().sort_values("Negative",ascending=False).head()
df1


Content_Rating_sentiment=pd.crosstab(merge_data["Content Rating"],merge_data.Sentiment).reset_index().sort_values("Positive",ascending=False)
Content_Rating_sentiment.head()
Content_Rating_sentimentn=pd.crosstab(merge_data["Content Rating"],merge_data.Sentiment).reset_index().sort_values("Negative",ascending=False)
Content_Rating_sentimentn
#we can observe Everyone , Teen, Mature 17+ , Everyone 10+, Adults only 18+ have recevied more +ve comments
# Everyone and teen gave also received high -ve comments might be due to more downloads and common content Rating
# Out:
# Sentiment   Content Rating  Negative  Neutral  Positive
# 1                 Everyone      4601     3320     14374
# 4                     Teen       818      348      2059
# 3               Mature 17+       352      264      1003
# 2             Everyone 10+       280      118       678
# 0          Adults only 18+         6        3        26

# %%
#Ploting bar chart
fig,axes=plt.subplots(2,2,figsize=(15,8))
sns.barplot(x=df['Category'], y=df['Positive'], ax=axes[0,0],palette="magma")
axes[0][0].set_title('Top 5 Category with +ve Sentiment')
axes[0][0].set_ylabel("Total +ve Sentiment")


sns.barplot(x=df1['Category'], y=df1['Negative'], ax=axes[0,1],palette="plasma")
axes[0,1].set_title("Top 5 Category with -ve Sentiment")
axes[0,1].set_ylabel("Total -ve Sentiment")


sns.barplot(x=Content_Rating_sentiment['Content Rating'], y=Content_Rating_sentiment['Positive'], ax=axes[1,0],palette="cividis")
axes[1,0].set_title('Content Rating vs +ve Sentiment')
axes[1][0].set_ylabel("Total +ve Sentiment")

sns.barplot(x=Content_Rating_sentimentn['Content Rating'], y=Content_Rating_sentimentn['Negative'], ax=axes[1,1],palette="inferno")
axes[1,1].set_title('Content Rating vs -ve Sentiment')
axes[1,1].set_ylabel("Total -ve Sentiment")

plt.tight_layout()
# Out:
# <ipython-input-412-2c45c3b287fb>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=df['Category'], y=df['Positive'], ax=axes[0,0],palette="magma")
# <ipython-input-412-2c45c3b287fb>:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=df1['Category'], y=df1['Negative'], ax=axes[0,1],palette="plasma")
# <ipython-input-412-2c45c3b287fb>:13: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=Content_Rating_sentiment['Content Rating'], y=Content_Rating_sentiment['Positive'], ax=axes[1,0],palette="cividis")
# ...

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Bar charts are ideal for comparing different categories and can display a wide range of data types, from numerical to categorical.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * We can observe that Game , Family , health_and_fitness , Tools and Finance are the top 5 Category with +ve Sentiment with most prefered age group everyone.
# * We can observe , Game , family ,Finance,Sports  , travel and local , finance have are top 5 -ve sentiment category.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Games , Family, Tools , Finance , helath and Fitness with age group of everyone should be considered for app development and launch for +ve response from the consumer.

# %% [markdown]
# #### Chart - 19 Sentiment_Polarity vs Sentiment_Subjectivity (Bivariate)

# %%
# Chart - 19 visualization code
print(df_user_reveiw.select_dtypes(exclude="object").corr())
sns.scatterplot(x=df_user_reveiw["Sentiment_Polarity"],y=df_user_reveiw["Sentiment_Subjectivity"],data=df_user_reveiw,hue="Sentiment")
plt.title("Sentiment_Polarity vs Sentiment_Subjectivity")
# sns.heatmap(df_user_reveiw.select_dtypes(exclude="object")).corr()
# Out:
#                         Sentiment_Polarity  Sentiment_Subjectivity
# Sentiment_Polarity                1.000000                0.272284
# Sentiment_Subjectivity            0.272284                1.000000
# Text(0.5, 1.0, 'Sentiment_Polarity vs Sentiment_Subjectivity')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Scater Plot is used to find the corelation between the two variables. To check the correlation between Sentiment Polarity and Sentiment Subjectivity , sactter plot is the most prefered option.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# We can observe here that Sentiment Polarity and Sentiment Subjectivity are slighltly positively correlated and distribution of +ve sentiments are more in comparison with -ve sentiments

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Sentiment Subjectivity and Sentiment polarity plays important role in sentiment analysis.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 20 - Correlation Heatmap

# %%
# Chart - 20 visualization code
# Correlation Heatmap visualization code
#checking on merged data frame
sns.heatmap(merge_data.select_dtypes(exclude="object").corr(),annot=True)
# Out:
# <Axes: >

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Heatmap is the best for correlation, a correlation matrix is a table showing correlation coefficients between two variables and is used to summarize data.The range of correlation is [-1,1].

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * We can observe here that Installs and Reviews are correlated
# * Rating and last updated are also slightly correlated +vely
# * Size and Last update is also slightly correlated +vely

# %% [markdown]
# #### Chart - 21 - Pair Plot

# %%
# Chart - 21 visualization code
# Pair Plot visualization code
sns.pairplot(merge_data.select_dtypes(exclude="object"))

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A pair plot, also known as a scatterplot matrix, is a powerful visualization tool that displays pairwise relationships in a dataset. It is particularly useful for exploring the relationships between multiple variables in a dataset.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# We can quickly have the overview of distribution and correlation between varaibles before proceeding with further analysis.
# * We can observe here that Reveiws and Installs are +vely correlated
# * Sentiment polarity and sentiment subjectivity is also slightly +vely correlated.

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?
# Explain Briefly.

# %% [markdown]
# **Below mentioned factors needs to be considered for developing app successfully**
#
# **Category** - Family, Games, Tools, Business, Communication
# *  Reason - Top 5 downloaded category, with average ratings above 4, having highest count of reviews.
#
# **Type** - Free
# * Reason - Free applications are most downloaded and preferred by consumers with 99.9%  downloads for category Game, Communication, Tools, Productivity,  Social.
#
#
# **Genre** - Communication , Tools, Productivity , Social ,Photography
# * Communication , Tools, Productivity , Social ,Photography are the most preferred and downloaded genere apps considering free section.
# * Action, Arcade and adventure, Personalization, puzzle, role playing are the most downloaded genre apps considering paid section.
# * Also we can observe under most downloaded Game category under free section arcade, action ,casual, Racing ,puzzle are more preferred by the consumer.
#
# **Content Rating** - Everyone
# *  Everyone age group have the most number of installs with 69.5%.
#
# **Size** - 10-19 MB
# * Apps to be developed between size 10-19 MB considering the number of downloads.
# * App size can be preferred 90-100mb  and 20-29 mb based on most downloads and  average rating above 4 and maximum download for paid section.
#
# **Android Version** - Varies with Device or 4 & Above
# * Android version should be considered varies with device as first priority(52%) and second option (43.5%) of 4 and above.
#
# **Paid Apps**
# * Grouping the paid section , found that most downloads are for apps pricing below 10$  in comparison with other price categories , however maximum price observed was till 400 Dollar and age group with maximum download under paid section is that of  Everyone.
# * Most revenue generated Category is Family (46.2%) , Lifestyle (23.4%) and game (16.55).
# * Most revenue generated  Genres are Arcade Action and adventure (35.8%),Lifestyle(29.5%) and Action 15.9%.
# * Minecraft is most revenue (47.6%) generated app in playstore.
#
# **Based on Sentiment**
# * Game, Health and Fitness , Family , Tools, Finance are the top 5 categories with maximum +ve sentiment received from consumer end with age group that of Everyone.
#
#
# **Based on Ratings and Reviews**
# - Timely Updates needs to be rolled out to improve the performance and quality of the app and to keep the consumer engaged, considering the reviews leading to improvement in Average rating.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# **The exploratory data analysis of the Play Store app data has provided valuable insights into various aspects of app performance, user behavior, and market trends. Below are the key findings and their implications:**
#
# **Top App Categories:**
#
# - **Findings**- Family, Games, Tools, Business, Communication categories are mostly downloaded , also having good rating above 4 and good count of reviews.
# - **Suggestions**- These category apps are majorly downloaded and same can be considered for acquiring new consumers.
#
# **Free Vs Paid:**
#
# - **Findings** - Free applications are downloaded majorly by consumers with a whole percentage of 99.9%.
# - **Suggestions** - Apps should be developed under free section and for paid section prize should be kept below 10$.
#
# **Genre:**
#
# - **Findings**-Communication , Tools, Productivity , Social ,Photography are the most preferred and downloaded at consumer end. Under Games Category - most downloaded apps are under Genre -arcade, action ,casual, Racing ,puzzle.
# - **Suggestions** - Developers should focus on developing apps under above mentioned genres.
#
# **Content Rating:**
#
# - **Findings** -  Everyone age group have the most number of installs with 69.5%.
# - **Suggestions** - Everyone age group should be considered for developing new app , increasing the audience count.
#
# **Size of App :**
#
# - **Findings** - Consumers tend to download small apps ,and here size group 10-19 MB was majorly installed. For paid section installs were also for 90-100mb and 20-29 mb .
# - **Suggestion** : App should be light weight with good quality and size should be between 10-19 MB.
#
# **Android Version :**
#
# - **Findings** - 52% downloads was for Android Version - Varies with Device and 43.5% downloads for Android version 4 and above.
# - **Suggestions** - Developer should consider android version which varies with the device of above 4 to develop apps.
#
# **Paid Apps :**
#
# - **Findings** -
#
#  - Most revenue generated Category is Family (46.2%) , Lifestyle (23.4%) and game (16.55%) allover.
#  - Most revenue generated Genres are Arcade Action and adventure (35.8%),Lifestyle(29.5%) and Action 15.9%.
#  - Minecraft is most revenue (47.6%) generated app in play store.
#
# - **Suggestions** - Developers should focus in Family ,Lifestyle and Games with genres Arcade Action and Adventure , Lifestyle and Action for developing paid apps in case with everyone Age Group.
#
# **Findings Based on Apps**
#
# - Google News , Maps - Navigate & Explore , Google Street View , YouTube, Google Play Movies & TV ,Google+ ,Instagram , Facebook , Google, Google Play Books are top 10 most installed apps in play store.
# - ColorNote Notepad  Notes, Calorie Counter-Macros, Family Locator - GPS Tracker,Calorie Counter - MyNetDiary, 8fit Workouts & Meal Planner are top 5 most +ve sentiment apps.
#
# - Overall Sentiment is 64% Positive , 21.3% Negative , 14.7% Neutral.
#
# **Findings Based on sentiment** - Game, Health and Fitness , Family , Tools, Finance are the top 5 categories with maximum +ve sentiment received from consumer end with age group that of Everyone.
#
# **Findings Based on Ratings and Reviews** - Timely Updates needs to be rolled out to improve the performance and quality of the app and to keep the consumer engaged, considering the reviews leading to improvement in Average rating.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your EDA Capstone Project !!!***
